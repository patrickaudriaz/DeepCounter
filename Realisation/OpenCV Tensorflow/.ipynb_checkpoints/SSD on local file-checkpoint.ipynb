# %% [markdown]
# # Imports

# %%
import cv2

import os
import time
import sys
import numpy as np
from matplotlib import pyplot as plt
import imutils
from imutils.video import VideoStream
from imutils.video import FPS
from scipy.spatial import distance as dist
from collections import OrderedDict

# used for tracking
import dlib

os.sys.path
# Out:
# ['/home/patrickaudriaz/tb-audriaz/Realisation/OpenCV Tensorflow',
#  '/home/patrickaudriaz/anaconda3/lib/python37.zip',
#  '/home/patrickaudriaz/anaconda3/lib/python3.7',
#  '/home/patrickaudriaz/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/home/patrickaudriaz/.local/lib/python3.7/site-packages',
#  '/home/patrickaudriaz/anaconda3/lib/python3.7/site-packages',
#  '/home/patrickaudriaz/.local/lib/python3.7/site-packages/IPython/extensions',
#  '/home/patrickaudriaz/.ipython']

# %% [markdown]
# # Global variables

# %%
streamIP = "http://160.98.31.178:8080/stream/video.mjpeg"

inputFile = "../../../data/dataset/pi2_15.mp4"
outputFile = "../../../data/output tf/pi22_tf_inc_10.avi"

# minimum probability to filter weak detections
minConfidence = 0.3

elapsedFrames = 0

# switch between detection and tracking
# set number of frames to skip before doing a detection
skipFrames = 2

FPSUpdate = 200
liveFPS = 0

# Width of network's input image
inputWidth = 300
# Height of network's input image
inputHeight = 300

font = cv2.FONT_HERSHEY_SIMPLEX

pbFile = "tf/ssd_inception_frozen_inference_graph.pb"
pbtxtFile = "tf/ssd_inception_v2_coco_2017_11_17.pbtxt"

modelName = "SSD Inception V2"

status = "off"

# WRITER to save computed stream to device
writer = None

# %% [markdown]
# # Read the input

# %%
# vs = cv2.VideoCapture(streamIP)

vs = cv2.VideoCapture(inputFile)

# get total frame to compute remaining processing time
prop = cv2.CAP_PROP_FRAME_COUNT
totalFrames = int(vs.get(prop))
print("[INFO] {} total frames in video".format(totalFrames))

H = int(vs.get(cv2.CAP_PROP_FRAME_HEIGHT))
W = int(vs.get(cv2.CAP_PROP_FRAME_WIDTH))

limitIn = int(H / 2 + H / 6)
limitOut = int(H / 2 - H / 6)

print(W, H)
# Out:
# [INFO] 129800 total frames in video
# 960 480

# %% [markdown]
# # Load model and classes

# %%
print("[INFO] loading model from disk...")

# Give the configuration and weight files for the model and load the
# network using them.
net = cv2.dnn.readNetFromTensorflow(pbFile, pbtxtFile)

print("[INFO] ... done !")
# Out:
# [INFO] loading model from disk...
# [INFO] ... done !

# %% [markdown]
# # Functions

# %%
# function to draw bounding box on the detected object
def drawBoundingBox(frame, box, centroid, color):
    (startX, startY, endX, endY) = box

    # draw a red rectangle around detected objects
    cv2.rectangle(
        frame, (int(startX), int(startY)), (int(endX), int(endY)), color, thickness=2
    )


# return coordinates of the center (centroid) of a bbox
def computeCentroid(box):
    (startX, startY, endX, endY) = box
    return np.array([startX + ((endX - startX) / 2), startY + ((endY - startY) / 2)])

# %% [markdown]
# # Tracking

# %%
# for every bounding box detected, a trackeable object is created
# to follow his path througn the frame
class TrackableObject:
    def __init__(self, objectID, centroid, zone):
        # store the object ID, then initialize a list of centroids
        # using the current centroid
        self.objectID = objectID
        self.centroids = [centroid]
        self.zone = zone

# %%
class CentroidTracker:
    def __init__(self, maxDisappeared=50, maxDistance=50):
        # initialize the next unique object ID along with two ordered
        # dictionaries used to keep track of mapping a given object
        # ID to its centroid and number of consecutive frames it has
        # been marked as "disappeared", respectively
        self.nextObjectID = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()

        # store the number of maximum consecutive frames a given
        # object is allowed to be marked as "disappeared" until we
        # need to deregister the object from tracking
        self.maxDisappeared = maxDisappeared

        # store the maximum distance between centroids to associate
        # an object -- if the distance is larger than this maximum
        # distance we'll start to mark the object as "disappeared"
        self.maxDistance = maxDistance

    def register(self, centroid):
        # when registering an object we use the next available object
        # ID to store the centroid
        self.objects[self.nextObjectID] = centroid
        self.disappeared[self.nextObjectID] = 0
        self.nextObjectID += 1

    def deregister(self, objectID):
        # to deregister an object ID we delete the object ID from
        # both of our respective dictionaries
        del self.objects[objectID]
        del self.disappeared[objectID]

    def update(self, rects):
        # check to see if the list of input bounding box rectangles
        # is empty
        if len(rects) == 0:
            # loop over any existing tracked objects and mark them
            # as disappeared
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1

                # if we have reached a maximum number of consecutive
                # frames where a given object has been marked as
                # missing, deregister it
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)

            # return early as there are no centroids or tracking info
            # to update
            return self.objects

        # initialize an array of input centroids for the current frame
        inputCentroids = np.zeros((len(rects), 2), dtype="int")

        # loop over the bounding box rectangles
        for (i, (startX, startY, endX, endY)) in enumerate(rects):
            # use the bounding box coordinates to derive the centroid
            cX = int((startX + endX) / 2.0)
            cY = int((startY + endY) / 2.0)
            inputCentroids[i] = (cX, cY)

        # if we are currently not tracking any objects take the input
        # centroids and register each of them
        if len(self.objects) == 0:
            for i in range(0, len(inputCentroids)):
                self.register(inputCentroids[i])

        # otherwise, are are currently tracking objects so we need to
        # try to match the input centroids to existing object
        # centroids
        else:
            # grab the set of object IDs and corresponding centroids
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())

            # compute the distance between each pair of object
            # centroids and input centroids, respectively -- our
            # goal will be to match an input centroid to an existing
            # object centroid
            D = dist.cdist(np.array(objectCentroids), inputCentroids)

            # in order to perform this matching we must (1) find the
            # smallest value in each row and then (2) sort the row
            # indexes based on their minimum values so that the row
            # with the smallest value as at the *front* of the index
            # list
            rows = D.min(axis=1).argsort()

            # next, we perform a similar process on the columns by
            # finding the smallest value in each column and then
            # sorting using the previously computed row index list
            cols = D.argmin(axis=1)[rows]

            # in order to determine if we need to update, register,
            # or deregister an object we need to keep track of which
            # of the rows and column indexes we have already examined
            usedRows = set()
            usedCols = set()

            # loop over the combination of the (row, column) index
            # tuples
            for (row, col) in zip(rows, cols):
                # if we have already examined either the row or
                # column value before, ignore it
                if row in usedRows or col in usedCols:
                    continue

                # if the distance between centroids is greater than
                # the maximum distance, do not associate the two
                # centroids to the same object
                if D[row, col] > self.maxDistance:
                    continue

                # otherwise, grab the object ID for the current row,
                # set its new centroid, and reset the disappeared
                # counter
                objectID = objectIDs[row]
                self.objects[objectID] = inputCentroids[col]
                self.disappeared[objectID] = 0

                # indicate that we have examined each of the row and
                # column indexes, respectively
                usedRows.add(row)
                usedCols.add(col)

            # compute both the row and column index we have NOT yet
            # examined
            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            # in the event that the number of object centroids is
            # equal or greater than the number of input centroids
            # we need to check and see if some of these objects have
            # potentially disappeared
            if D.shape[0] >= D.shape[1]:
                # loop over the unused row indexes
                for row in unusedRows:
                    # grab the object ID for the corresponding row
                    # index and increment the disappeared counter
                    objectID = objectIDs[row]
                    self.disappeared[objectID] += 1

                    # check to see if the number of consecutive
                    # frames the object has been marked "disappeared"
                    # for warrants deregistering the object
                    if self.disappeared[objectID] > self.maxDisappeared:
                        self.deregister(objectID)

            # otherwise, if the number of input centroids is greater
            # than the number of existing object centroids we need to
            # register each new input centroid as a trackable object
            else:
                for col in unusedCols:
                    self.register(inputCentroids[col])

        # return the set of trackable objects
        return self.objects

# %% [markdown]
# # Processing

# %%
# object detection using SSD
def detect(frame, detections):
    # loop over the detections
    for detection in detections[0, 0, :, :]:
        confidence = float(detection[2])

        # if the confidence is above a threshold
        if confidence > minConfidence:
            classID = detection[1]

            # proceed only if the object detected is indeed a human
            if classID == 1:
                # get coordinates of the bbox
                left = detection[3] * W
                top = detection[4] * H
                right = detection[5] * W
                bottom = detection[6] * H

                box = [left, top, right, bottom]

                # construct a dlib rectangle object from the bounding
                # box coordinates and then start the dlib correlation
                # tracker
                tracker = dlib.correlation_tracker()
                rect = dlib.rectangle(int(left), int(top), int(right), int(bottom))

                tracker.start_track(frame, rect)

                trackers.append(tracker)

                rects.append(box)

                centroid = computeCentroid(box)

                drawBoundingBox(frame, box, centroid, color=(0, 0, 255))

                cv2.putText(
                    frame, status, (0, 115), font, 0.5, (0, 255, 0), 1, cv2.LINE_AA
                )


# object tracking using dlib and centroid tracker
def track(frame, trackers):
    for tracker in trackers:
        status = "Tracking"
        # update the tracker and grab the position of the tracked
        # object
        tracker.update(frame)

        pos = tracker.get_position()

        # unpack the position object
        left = int(pos.left())
        top = int(pos.top())
        right = int(pos.right())
        bottom = int(pos.bottom())

        box = [left, top, right, bottom]

        rects.append(box)

        centroid = computeCentroid(box)

        drawBoundingBox(frame, box, centroid, color=(0, 128, 255))

        cv2.putText(frame, status, (0, 95), font, 0.5, (0, 255, 0), 1, cv2.LINE_AA)

# %% [markdown]
# # Counting

# %%
# people counting logic based on zone of appearance
def counting(objects):

    global totalIn
    global totalOut

    # loop over the tracked objects
    for (objectID, centroid) in objects.items():

        # check to see if a trackable object exists for the current
        # object ID
        to = trackableObjects.get(objectID, None)

        # if there is no existing trackable object, create one
        if to is None:
            # define starting zone of the trackeable object (IN or OUT)
            if centroid[1] >= H / 2:
                zone = "in"
            else:
                zone = "out"

            to = TrackableObject(objectID, centroid, zone)

        # otherwise, there is a trackable object so we can utilize it
        # to determine direction
        else:
            if to.zone == "in":
                if centroid[1] < limitOut:
                    totalOut += 1
                    to.zone = "out"
                    print("OUT : ", totalOut)

            elif to.zone == "out":
                if centroid[1] > limitIn:
                    totalIn += 1
                    to.zone = "in"
                    print("IN : ", totalIn)

            to.centroids.append(centroid)

        # store the trackable object in our dictionary
        trackableObjects[objectID] = to

        # draw both the ID of the object and the centroid of the
        # object on the output frame
        cv2.circle(frame, (centroid[0], centroid[1]), 4, (0, 0, 255), -1)
        cv2.putText(
            frame,
            "ID : " + str(objectID),
            (centroid[0], centroid[1] + 20),
            font,
            0.6,
            (0, 0, 255),
            1,
            cv2.LINE_AA,
        )

# %% [markdown]
# # For each frames

# %%
# initialize t dlib correlation tracker and CentroidTracker
ct = CentroidTracker(maxDisappeared=30, maxDistance=130)

trackers = []
trackableObjects = {}

totalOut = 0
totalIn = 0

# start the frames per second throughput estimator
fps = FPS().start()
totalFPS = FPS().start()

# loop over frames from the video file stream
while True:
    # read the next frame from the file
    (grabbed, frame) = vs.read()

    # if the frame was not grabbed, then we have reached the end
    # of the stream
    if not grabbed:
        print("Done processing !!!")
        break

    # list of detected rectangles
    rects = []

    # object detection only every n frames to improve performances
    # strat dlib correlation tracker on detections
    if elapsedFrames % skipFrames == 0:
        trackers = []
        status = "Detecting"

        # Create the blob with a size of (300, 300)
        blob = cv2.dnn.blobFromImage(
            frame, size=(inputWidth, inputHeight), swapRB=True, crop=False
        )

        # Feed the input blob to the network, perform inference and get the output:
        # Set the input for the network
        net.setInput(blob)

        start = time.time()
        detections = net.forward()
        end = time.time()

        detect(frame, detections)

    # do tracking using detection data on every other frame
    else:
        track(frame, trackers)

    objects = ct.update(rects)
    counting(objects)

    # draw a two horizontal lines across the frame serving as boundaries
    # one for peoples going IN and an other for OUT
    cv2.line(frame, (0, limitIn), (W, limitIn), (0, 255, 255), 1)
    cv2.line(frame, (0, limitOut), (W, limitOut), (255, 255, 0), 1)

    # construct a tuple of information we will be displaying on the
    # frame
    info = [("Out", totalOut), ("In", totalIn)]

    # loop over the info tuples and draw them on our frame
    for (i, (k, v)) in enumerate(info):
        text = "{}: {}".format(k, v)
        cv2.putText(
            frame,
            text,
            (10, H - ((i * 20) + 20)),
            font,
            0.6,
            (0, 255, 255),
            1,
            cv2.LINE_AA,
        )

    # increment the total number of frames processed thus far and
    # then update the FPS counter
    elapsedFrames += 1
    fps.update()

    # time remaining estimator for local files processing
    if elapsedFrames % FPSUpdate == 0:
        fps.stop()
        liveFPS = fps.fps()
        print(
            "[INFO] Time remaining (min) : {:.1f}".format(
                (totalFrames - elapsedFrames) / int(liveFPS) / 60
            )
        )

        # start the frames per second throughput estimator
        fps = FPS().start()

    # draw metadatas on the frame
    cv2.putText(
        frame, "Model : " + modelName, (0, 15), font, 0.5, (0, 255, 0), 1, cv2.LINE_AA
    )
    cv2.putText(
        frame,
        "Resolution : " + str(W) + "x" + str(H),
        (0, 35),
        font,
        0.5,
        (0, 255, 0),
        1,
        cv2.LINE_AA,
    )
    cv2.putText(
        frame,
        "FPS: {:.1f}".format(liveFPS),
        (0, 55),
        font,
        0.5,
        (0, 255, 0),
        1,
        cv2.LINE_AA,
    )
    cv2.putText(
        frame,
        "Detection : {:.2f} sec".format(end - start),
        (0, 75),
        font,
        0.5,
        (0, 255, 0),
        1,
        cv2.LINE_AA,
    )

    totalFPS.update()

    # show the video beeing processed live
    cv2.imshow("RPI", frame)

    #     # check if the video writer is None
    #     if writer is None:
    #         # initialize our video writer
    #         fourcc = cv2.VideoWriter_fourcc(*"MJPG")
    #         writer = cv2.VideoWriter(outputFile, fourcc, 30, (W, H), True)
    #         print("writing...")

    #     # write the output frame to disk
    #     writer.write(frame)

    if cv2.waitKey(1) == ord("q"):
        break

totalFPS.stop()
print("[INFO] approx. FPS: {:.2f}".format(totalFPS.fps()))
print("OUT : ", totalOut)
print("IN : ", totalIn)

# release the file pointers
vs.release()
# writer.release()

# close any open windows
cv2.destroyAllWindows()
# Out:
# [INFO] Time remaining (min) : 120.0
# [INFO] Time remaining (min) : 239.6
# [INFO] Time remaining (min) : 269.2
# [INFO] Time remaining (min) : 268.8
# [INFO] Time remaining (min) : 268.3
# [INFO] Time remaining (min) : 267.9
# OUT :  1
# OUT :  2
# [INFO] Time remaining (min) : 305.7
# [INFO] Time remaining (min) : 267.1
# [INFO] Time remaining (min) : 266.7
# [INFO] Time remaining (min) : 266.2
# [INFO] Time remaining (min) : 265.8
# OUT :  3
# [INFO] Time remaining (min) : 265.4
# [INFO] Time remaining (min) : 265.0
# [INFO] Time remaining (min) : 264.6
# OUT :  4
# OUT :  5
# OUT :  6
# [INFO] Time remaining (min) : 301.9
# [INFO] Time remaining (min) : 263.8
# [INFO] Time remaining (min) : 263.3
# [INFO] Time remaining (min) : 262.9
# OUT :  7
# OUT :  8
# [INFO] Time remaining (min) : 300.0
# [INFO] Time remaining (min) : 262.1
# [INFO] Time remaining (min) : 261.7
# OUT :  9
# OUT :  10
# [INFO] Time remaining (min) : 261.2
# [INFO] Time remaining (min) : 260.8
# [INFO] Time remaining (min) : 260.4
# [INFO] Time remaining (min) : 260.0
# [INFO] Time remaining (min) : 259.6
# [INFO] Time remaining (min) : 259.2
# OUT :  11
# [INFO] Time remaining (min) : 258.8
# [INFO] Time remaining (min) : 258.3
# OUT :  12
# OUT :  13
# [INFO] Time remaining (min) : 294.8
# [INFO] Time remaining (min) : 257.5
# [INFO] Time remaining (min) : 257.1
# [INFO] Time remaining (min) : 256.7
# [INFO] Time remaining (min) : 256.2
# [INFO] Time remaining (min) : 255.8
# [INFO] Time remaining (min) : 255.4
# IN :  1
# IN :  2
# IN :  3
# [INFO] Time remaining (min) : 291.4
# [INFO] Time remaining (min) : 254.6
# [INFO] Time remaining (min) : 254.2
# [INFO] Time remaining (min) : 253.8
# [INFO] Time remaining (min) : 253.3
# [INFO] Time remaining (min) : 252.9
# [INFO] Time remaining (min) : 252.5
# [INFO] Time remaining (min) : 252.1
# [INFO] Time remaining (min) : 251.7
# [INFO] Time remaining (min) : 287.1
# OUT :  14
# OUT :  15
# OUT :  16
# OUT :  17
# OUT :  18
# [INFO] Time remaining (min) : 334.4
# [INFO] Time remaining (min) : 250.4
# OUT :  19
# [INFO] Time remaining (min) : 285.7
# [INFO] Time remaining (min) : 249.6
# [INFO] Time remaining (min) : 249.2
# [INFO] Time remaining (min) : 248.8
# [INFO] Time remaining (min) : 248.3
# [INFO] Time remaining (min) : 247.9
# [INFO] Time remaining (min) : 247.5
# [INFO] Time remaining (min) : 247.1
# [INFO] Time remaining (min) : 246.7
# [INFO] Time remaining (min) : 246.2
# [INFO] Time remaining (min) : 245.8
# IN :  4
# [INFO] Time remaining (min) : 245.4
# OUT :  20
# OUT :  21
# [INFO] Time remaining (min) : 280.0
# [INFO] Time remaining (min) : 244.6
# OUT :  22
# [INFO] Time remaining (min) : 244.2
# [INFO] Time remaining (min) : 243.8
# [INFO] Time remaining (min) : 243.3
# [INFO] Time remaining (min) : 242.9
# [INFO] Time remaining (min) : 242.5
# [INFO] Time remaining (min) : 242.1
# [INFO] Time remaining (min) : 241.7
# [INFO] Time remaining (min) : 275.7
# IN :  5
# [INFO] Time remaining (min) : 240.8
# [INFO] Time remaining (min) : 240.4
# [INFO] Time remaining (min) : 240.0
# OUT :  23
# [INFO] Time remaining (min) : 239.6
# OUT :  24
# OUT :  25
# OUT :  26
# OUT :  27
# [INFO] Time remaining (min) : 273.3
# [INFO] Time remaining (min) : 238.8
# [INFO] Time remaining (min) : 238.3
# [INFO] Time remaining (min) : 237.9
# [INFO] Time remaining (min) : 237.5
# [INFO] Time remaining (min) : 237.1
# [INFO] Time remaining (min) : 236.7
# [INFO] Time remaining (min) : 236.2
# [INFO] Time remaining (min) : 235.8
# [INFO] Time remaining (min) : 235.4
# [INFO] Time remaining (min) : 235.0
# IN :  6
# IN :  7
# IN :  8
# IN :  9
# [INFO] Time remaining (min) : 268.1
# IN :  10
# [INFO] Time remaining (min) : 234.2
# [INFO] Time remaining (min) : 233.8
# [INFO] Time remaining (min) : 233.3
# OUT :  28
# IN :  11
# [INFO] Time remaining (min) : 186.3
# [INFO] Time remaining (min) : 169.1
# OUT :  29
# IN :  12
# [INFO] Time remaining (min) : 185.7
# [INFO] Time remaining (min) : 185.3
# [INFO] Time remaining (min) : 168.2
# [INFO] Time remaining (min) : 167.9
# [INFO] Time remaining (min) : 167.6
# [INFO] Time remaining (min) : 167.3
# [INFO] Time remaining (min) : 167.0
# OUT :  30
# OUT :  31
# [INFO] Time remaining (min) : 183.3
# IN :  13
# [INFO] Time remaining (min) : 183.0
# [INFO] Time remaining (min) : 166.1
# [INFO] Time remaining (min) : 165.8
# [INFO] Time remaining (min) : 165.5
# [INFO] Time remaining (min) : 165.2
# [INFO] Time remaining (min) : 164.8
# [INFO] Time remaining (min) : 164.5
# [INFO] Time remaining (min) : 164.2
# [INFO] Time remaining (min) : 163.9
# [INFO] Time remaining (min) : 163.6
# OUT :  32
# [INFO] Time remaining (min) : 163.3
# [INFO] Time remaining (min) : 163.0
# [INFO] Time remaining (min) : 162.7
# [INFO] Time remaining (min) : 162.4
# [INFO] Time remaining (min) : 162.1
# OUT :  33
# [INFO] Time remaining (min) : 178.0
# [INFO] Time remaining (min) : 161.5
# [INFO] Time remaining (min) : 161.2
# OUT :  34
# OUT :  35
# IN :  14
# [INFO] Time remaining (min) : 196.7
# IN :  15
# IN :  16
# IN :  17
# OUT :  36
# OUT :  37
# [INFO] Time remaining (min) : 196.3
# [INFO] Time remaining (min) : 160.3
# [INFO] Time remaining (min) : 160.0
# OUT :  38
# [INFO] Time remaining (min) : 175.7
# [INFO] Time remaining (min) : 159.4
# [INFO] Time remaining (min) : 159.1
# [INFO] Time remaining (min) : 158.8
# [INFO] Time remaining (min) : 158.5
# IN :  18
# [INFO] Time remaining (min) : 174.0
# OUT :  39
# [INFO] Time remaining (min) : 173.7
# [INFO] Time remaining (min) : 157.6
# OUT :  40
# OUT :  41
# [INFO] Time remaining (min) : 173.0
# [INFO] Time remaining (min) : 157.0
# OUT :  42
# [INFO] Time remaining (min) : 172.3
# OUT :  43
# [INFO] Time remaining (min) : 172.0
# [INFO] Time remaining (min) : 156.1
# [INFO] Time remaining (min) : 155.8
# [INFO] Time remaining (min) : 155.5
# IN :  19
# IN :  20
# [INFO] Time remaining (min) : 170.7
# OUT :  44
# [INFO] Time remaining (min) : 154.8
# OUT :  45
# [INFO] Time remaining (min) : 170.0
# [INFO] Time remaining (min) : 154.2
# [INFO] Time remaining (min) : 169.3
# [INFO] Time remaining (min) : 153.6
# OUT :  46
# [INFO] Time remaining (min) : 168.7
# [INFO] Time remaining (min) : 153.0
# OUT :  47
# OUT :  48
# [INFO] Time remaining (min) : 168.0
# OUT :  49
# [INFO] Time remaining (min) : 167.7
# [INFO] Time remaining (min) : 152.1
# [INFO] Time remaining (min) : 167.0
# OUT :  50
# [INFO] Time remaining (min) : 166.7
# IN :  21
# [INFO] Time remaining (min) : 166.3
# [INFO] Time remaining (min) : 150.9
# [INFO] Time remaining (min) : 150.6
# [INFO] Time remaining (min) : 150.3
# OUT :  51
# [INFO] Time remaining (min) : 165.0
# [INFO] Time remaining (min) : 164.7
# OUT :  52
# [INFO] Time remaining (min) : 164.3
# OUT :  53
# [INFO] Time remaining (min) : 149.1
# [INFO] Time remaining (min) : 163.7
# [INFO] Time remaining (min) : 148.5
# OUT :  54
# [INFO] Time remaining (min) : 163.0
# [INFO] Time remaining (min) : 147.9
# [INFO] Time remaining (min) : 162.3
# IN :  22
# [INFO] Time remaining (min) : 162.0
# [INFO] Time remaining (min) : 147.0
# IN :  23
# [INFO] Time remaining (min) : 161.3
# [INFO] Time remaining (min) : 146.4
# [INFO] Time remaining (min) : 146.1
# OUT :  55
# [INFO] Time remaining (min) : 160.3
# OUT :  56
# [INFO] Time remaining (min) : 160.0
# [INFO] Time remaining (min) : 159.7
# OUT :  57
# [INFO] Time remaining (min) : 159.3
# [INFO] Time remaining (min) : 144.5
# OUT :  58
# [INFO] Time remaining (min) : 158.7
# [INFO] Time remaining (min) : 158.3
# [INFO] Time remaining (min) : 158.0
# [INFO] Time remaining (min) : 157.7
# [INFO] Time remaining (min) : 157.3
# [INFO] Time remaining (min) : 142.7
# [INFO] Time remaining (min) : 142.4
# [INFO] Time remaining (min) : 142.1
# [INFO] Time remaining (min) : 141.8
# [INFO] Time remaining (min) : 155.7
# [INFO] Time remaining (min) : 141.2
# [INFO] Time remaining (min) : 140.9
# OUT :  59
# [INFO] Time remaining (min) : 154.7
# [INFO] Time remaining (min) : 154.3
# OUT :  60
# OUT :  61
# OUT :  62
# IN :  24
# [INFO] Time remaining (min) : 171.1
# [INFO] Time remaining (min) : 153.7
# [INFO] Time remaining (min) : 153.3
# [INFO] Time remaining (min) : 153.0
# [INFO] Time remaining (min) : 138.8
# OUT :  63
# [INFO] Time remaining (min) : 152.3
# [INFO] Time remaining (min) : 138.2
# IN :  25
# [INFO] Time remaining (min) : 151.7
# [INFO] Time remaining (min) : 151.3
# IN :  26
# IN :  27
# [INFO] Time remaining (min) : 151.0
# [INFO] Time remaining (min) : 137.0
# [INFO] Time remaining (min) : 136.7
# [INFO] Time remaining (min) : 136.4
# [INFO] Time remaining (min) : 136.1
# [INFO] Time remaining (min) : 135.8
# [INFO] Time remaining (min) : 135.5
# OUT :  64
# [INFO] Time remaining (min) : 148.7
# [INFO] Time remaining (min) : 134.8
# [INFO] Time remaining (min) : 148.0
# [INFO] Time remaining (min) : 134.2
# OUT :  65
# [INFO] Time remaining (min) : 147.3
# [INFO] Time remaining (min) : 133.6
# OUT :  66
# [INFO] Time remaining (min) : 146.7
# [INFO] Time remaining (min) : 133.0
# [INFO] Time remaining (min) : 132.7
# [INFO] Time remaining (min) : 132.4
# [INFO] Time remaining (min) : 132.1
# OUT :  67
# [INFO] Time remaining (min) : 145.0
# [INFO] Time remaining (min) : 131.5
# OUT :  68
# IN :  28
# OUT :  69
# [INFO] Time remaining (min) : 144.3
# [INFO] Time remaining (min) : 120.0
# [INFO] Time remaining (min) : 89.8
# [INFO] Time remaining (min) : 84.3
# [INFO] Time remaining (min) : 84.1
# [INFO] Time remaining (min) : 89.2
# [INFO] Time remaining (min) : 89.0
# OUT :  70
# IN :  29
# [INFO] Time remaining (min) : 94.7
# [INFO] Time remaining (min) : 83.3
# OUT :  71
# [INFO] Time remaining (min) : 88.3
# [INFO] Time remaining (min) : 88.1
# [INFO] Time remaining (min) : 100.5
# IN :  30
# IN :  31
# IN :  32
# IN :  33
# [INFO] Time remaining (min) : 107.9
# IN :  34
# IN :  35
# [INFO] Time remaining (min) : 100.0
# [INFO] Time remaining (min) : 87.3
# IN :  36
# [INFO] Time remaining (min) : 92.9
# [INFO] Time remaining (min) : 86.9
# [INFO] Time remaining (min) : 86.7
# IN :  37
# [INFO] Time remaining (min) : 92.2
# OUT :  72
# [INFO] Time remaining (min) : 92.0
# OUT :  73
# IN :  38
# [INFO] Time remaining (min) : 91.8
# [INFO] Time remaining (min) : 85.8
# [INFO] Time remaining (min) : 85.6
# [INFO] Time remaining (min) : 85.4
# OUT :  74
# OUT :  75
# [INFO] Time remaining (min) : 90.9
# [INFO] Time remaining (min) : 85.0
# [INFO] Time remaining (min) : 90.4
# IN :  39
# [INFO] Time remaining (min) : 84.6
# IN :  40
# [INFO] Time remaining (min) : 90.0
# [INFO] Time remaining (min) : 84.2
# [INFO] Time remaining (min) : 84.0
# [INFO] Time remaining (min) : 83.8
# [INFO] Time remaining (min) : 83.5
# IN :  41
# [INFO] Time remaining (min) : 88.9
# [INFO] Time remaining (min) : 83.1
# OUT :  76
# [INFO] Time remaining (min) : 88.4
# [INFO] Time remaining (min) : 88.2
# IN :  42
# IN :  43
# IN :  44
# [INFO] Time remaining (min) : 94.3
# IN :  45
# [INFO] Time remaining (min) : 82.3
# [INFO] Time remaining (min) : 82.1
# [INFO] Time remaining (min) : 81.9
# [INFO] Time remaining (min) : 81.7
# [INFO] Time remaining (min) : 86.9
# OUT :  77
# [INFO] Time remaining (min) : 86.7
# OUT :  78
# [INFO] Time remaining (min) : 86.4
# [INFO] Time remaining (min) : 80.8
# [INFO] Time remaining (min) : 80.6
# [INFO] Time remaining (min) : 80.4
# [INFO] Time remaining (min) : 85.6
# OUT :  79
# OUT :  80
# OUT :  81
# [INFO] Time remaining (min) : 91.4
# [INFO] Time remaining (min) : 79.8
# [INFO] Time remaining (min) : 79.6
# [INFO] Time remaining (min) : 79.4
# IN :  46
# [INFO] Time remaining (min) : 84.4
# [INFO] Time remaining (min) : 79.0
# [INFO] Time remaining (min) : 78.8
# [INFO] Time remaining (min) : 78.5
# OUT :  82
# [INFO] Time remaining (min) : 83.6
# [INFO] Time remaining (min) : 73.5
# [INFO] Time remaining (min) : 77.9
# [INFO] Time remaining (min) : 77.7
# [INFO] Time remaining (min) : 77.5
# [INFO] Time remaining (min) : 77.3
# [INFO] Time remaining (min) : 77.1
# IN :  47
# [INFO] Time remaining (min) : 76.9
# [INFO] Time remaining (min) : 76.7
# [INFO] Time remaining (min) : 76.5
# [INFO] Time remaining (min) : 76.2
# [INFO] Time remaining (min) : 76.0
# [INFO] Time remaining (min) : 75.8
# [INFO] Time remaining (min) : 71.2
# [INFO] Time remaining (min) : 75.4
# [INFO] Time remaining (min) : 75.2
# [INFO] Time remaining (min) : 75.0
# [INFO] Time remaining (min) : 74.8
# OUT :  83
# [INFO] Time remaining (min) : 79.6
# [INFO] Time remaining (min) : 74.4
# [INFO] Time remaining (min) : 69.8
# [INFO] Time remaining (min) : 74.0
# [INFO] Time remaining (min) : 73.8
# [INFO] Time remaining (min) : 73.5
# [INFO] Time remaining (min) : 73.3
# [INFO] Time remaining (min) : 78.0
# IN :  48
# [INFO] Time remaining (min) : 77.8
# [INFO] Time remaining (min) : 72.7
# [INFO] Time remaining (min) : 72.5
# IN :  49
# [INFO] Time remaining (min) : 72.3
# [INFO] Time remaining (min) : 72.1
# IN :  50
# [INFO] Time remaining (min) : 71.9
# [INFO] Time remaining (min) : 71.7
# [INFO] Time remaining (min) : 67.3
# [INFO] Time remaining (min) : 71.2
# [INFO] Time remaining (min) : 71.0
# IN :  51
# [INFO] Time remaining (min) : 75.6
# IN :  52
# IN :  53
# IN :  54
# IN :  55
# IN :  56
# [INFO] Time remaining (min) : 94.2
# [INFO] Time remaining (min) : 70.4
# IN :  57
# [INFO] Time remaining (min) : 74.9
# IN :  58
# IN :  59
# [INFO] Time remaining (min) : 80.0
# [INFO] Time remaining (min) : 69.8
# [INFO] Time remaining (min) : 69.6
# [INFO] Time remaining (min) : 69.4
# [INFO] Time remaining (min) : 69.2
# [INFO] Time remaining (min) : 73.6
# IN :  60
# IN :  61
# IN :  62
# IN :  63
# [INFO] Time remaining (min) : 84.6
# [INFO] Time remaining (min) : 68.5
# [INFO] Time remaining (min) : 68.3
# [INFO] Time remaining (min) : 68.1
# IN :  64
# IN :  65
# OUT :  84
# [INFO] Time remaining (min) : 90.6
# [INFO] Time remaining (min) : 77.4
# [INFO] Time remaining (min) : 77.1
# [INFO] Time remaining (min) : 67.3
# [INFO] Time remaining (min) : 76.7
# [INFO] Time remaining (min) : 82.3
# IN :  66
# IN :  67
# OUT :  85
# OUT :  86
# IN :  68
# IN :  69
# [INFO] Time remaining (min) : 88.9
# IN :  70
# IN :  71
# [INFO] Time remaining (min) : 76.0
# [INFO] Time remaining (min) : 62.4
# [INFO] Time remaining (min) : 62.2
# [INFO] Time remaining (min) : 65.8
# [INFO] Time remaining (min) : 70.0
# IN :  72
# IN :  73
# [INFO] Time remaining (min) : 87.2
# IN :  74
# IN :  75
# [INFO] Time remaining (min) : 74.5
# [INFO] Time remaining (min) : 65.0
# [INFO] Time remaining (min) : 64.8
# IN :  76
# [INFO] Time remaining (min) : 68.9
# [INFO] Time remaining (min) : 64.4
# [INFO] Time remaining (min) : 64.2
# [INFO] Time remaining (min) : 64.0
# [INFO] Time remaining (min) : 63.8
# [INFO] Time remaining (min) : 63.5
# [INFO] Time remaining (min) : 67.6
# IN :  77
# [INFO] Time remaining (min) : 63.1
# [INFO] Time remaining (min) : 62.9
# [INFO] Time remaining (min) : 62.7
# [INFO] Time remaining (min) : 62.5
# [INFO] Time remaining (min) : 62.3
# IN :  78
# [INFO] Time remaining (min) : 62.1
# [INFO] Time remaining (min) : 61.9
# OUT :  87
# [INFO] Time remaining (min) : 61.7
# IN :  79
# [INFO] Time remaining (min) : 65.6
# [INFO] Time remaining (min) : 57.6
# [INFO] Time remaining (min) : 61.0
# OUT :  88
# [INFO] Time remaining (min) : 64.9
# [INFO] Time remaining (min) : 60.6
# [INFO] Time remaining (min) : 60.4
# [INFO] Time remaining (min) : 60.2
# [INFO] Time remaining (min) : 60.0
# [INFO] Time remaining (min) : 59.8
# OUT :  89
# OUT :  90
# [INFO] Time remaining (min) : 68.1
# [INFO] Time remaining (min) : 59.4
# [INFO] Time remaining (min) : 59.2
# OUT :  91
# OUT :  92
# [INFO] Time remaining (min) : 62.9
# [INFO] Time remaining (min) : 58.8
# [INFO] Time remaining (min) : 58.5
# [INFO] Time remaining (min) : 58.3
# IN :  80
# [INFO] Time remaining (min) : 62.0
# OUT :  93
# OUT :  94
# [INFO] Time remaining (min) : 61.8
# [INFO] Time remaining (min) : 61.6
# [INFO] Time remaining (min) : 57.5
# [INFO] Time remaining (min) : 57.3
# [INFO] Time remaining (min) : 57.1
# [INFO] Time remaining (min) : 56.9
# [INFO] Time remaining (min) : 56.7
# IN :  81
# [INFO] Time remaining (min) : 60.2
# [INFO] Time remaining (min) : 56.2
# [INFO] Time remaining (min) : 56.0
# [INFO] Time remaining (min) : 55.8
# [INFO] Time remaining (min) : 55.6
# [INFO] Time remaining (min) : 55.4
# [INFO] Time remaining (min) : 58.9
# IN :  82
# IN :  83
# [INFO] Time remaining (min) : 55.0
# [INFO] Time remaining (min) : 54.8
# [INFO] Time remaining (min) : 54.6
# [INFO] Time remaining (min) : 54.4
# [INFO] Time remaining (min) : 54.2
# [INFO] Time remaining (min) : 54.0
# [INFO] Time remaining (min) : 53.8
# OUT :  95
# [INFO] Time remaining (min) : 57.1
# [INFO] Time remaining (min) : 53.3
# [INFO] Time remaining (min) : 53.1
# [INFO] Time remaining (min) : 52.9
# [INFO] Time remaining (min) : 52.7
# OUT :  96
# [INFO] Time remaining (min) : 56.0
# [INFO] Time remaining (min) : 52.3
# [INFO] Time remaining (min) : 52.1
# [INFO] Time remaining (min) : 51.9
# [INFO] Time remaining (min) : 51.7
# [INFO] Time remaining (min) : 51.5
# [INFO] Time remaining (min) : 51.2
# IN :  84
# [INFO] Time remaining (min) : 51.0
# [INFO] Time remaining (min) : 50.8
# [INFO] Time remaining (min) : 50.6
# [INFO] Time remaining (min) : 50.4
# [INFO] Time remaining (min) : 50.2
# [INFO] Time remaining (min) : 50.0
# OUT :  97
# OUT :  98
# [INFO] Time remaining (min) : 61.3
# [INFO] Time remaining (min) : 49.6
# [INFO] Time remaining (min) : 49.4
# IN :  85
# IN :  86
# [INFO] Time remaining (min) : 52.4
# [INFO] Time remaining (min) : 49.0
# [INFO] Time remaining (min) : 48.8
# [INFO] Time remaining (min) : 48.5
# IN :  87
# [INFO] Time remaining (min) : 48.3
# IN :  88
# IN :  89
# [INFO] Time remaining (min) : 55.0
# OUT :  99
# [INFO] Time remaining (min) : 47.9
# [INFO] Time remaining (min) : 47.7
# [INFO] Time remaining (min) : 47.5
# [INFO] Time remaining (min) : 47.3
# [INFO] Time remaining (min) : 47.1
# [INFO] Time remaining (min) : 46.9
# [INFO] Time remaining (min) : 46.7
# [INFO] Time remaining (min) : 46.5
# IN :  90
# [INFO] Time remaining (min) : 56.9
# IN :  91
# [INFO] Time remaining (min) : 52.6
# [INFO] Time remaining (min) : 45.8
# [INFO] Time remaining (min) : 45.6
# [INFO] Time remaining (min) : 45.4
# IN :  92
# IN :  93
# [INFO] Time remaining (min) : 26.8
# [INFO] Time remaining (min) : 24.0
# [INFO] Time remaining (min) : 24.7
# [INFO] Time remaining (min) : 23.8
# [INFO] Time remaining (min) : 24.5
# [INFO] Time remaining (min) : 24.4
# IN :  94
# [INFO] Time remaining (min) : 27.1
# [INFO] Time remaining (min) : 24.1
# [INFO] Time remaining (min) : 23.2
# [INFO] Time remaining (min) : 23.9
# IN :  95
# [INFO] Time remaining (min) : 24.6
# [INFO] Time remaining (min) : 22.9
# [INFO] Time remaining (min) : 23.6
# OUT :  100
# [INFO] Time remaining (min) : 24.3
# [INFO] Time remaining (min) : 22.6
# [INFO] Time remaining (min) : 23.2
# OUT :  101
# OUT :  102
# [INFO] Time remaining (min) : 25.8
# [INFO] Time remaining (min) : 23.0
# IN :  96
# IN :  97
# [INFO] Time remaining (min) : 26.5
# OUT :  103
# [INFO] Time remaining (min) : 22.8
# [INFO] Time remaining (min) : 22.6
# [INFO] Time remaining (min) : 22.5
# [INFO] Time remaining (min) : 22.4
# [INFO] Time remaining (min) : 21.6
# IN :  98
# IN :  99
# [INFO] Time remaining (min) : 29.2
# IN :  100
# IN :  101
# [INFO] Time remaining (min) : 23.7
# [INFO] Time remaining (min) : 22.0
# [INFO] Time remaining (min) : 21.1
# [INFO] Time remaining (min) : 21.0
# IN :  102
# [INFO] Time remaining (min) : 22.4
# [INFO] Time remaining (min) : 21.5
# [INFO] Time remaining (min) : 21.4
# [INFO] Time remaining (min) : 20.6
# [INFO] Time remaining (min) : 20.4
# OUT :  104
# [INFO] Time remaining (min) : 22.6
# IN :  103
# IN :  104
# [INFO] Time remaining (min) : 22.5
# [INFO] Time remaining (min) : 20.8
# IN :  105
# [INFO] Time remaining (min) : 21.4
# [INFO] Time remaining (min) : 20.6
# [INFO] Time remaining (min) : 19.8
# [INFO] Time remaining (min) : 20.3
# [INFO] Time remaining (min) : 19.6
# [INFO] Time remaining (min) : 20.1
# [INFO] Time remaining (min) : 19.3
# [INFO] Time remaining (min) : 19.9
# [INFO] Time remaining (min) : 19.1
# [INFO] Time remaining (min) : 19.0
# [INFO] Time remaining (min) : 19.5
# [INFO] Time remaining (min) : 18.8
# [INFO] Time remaining (min) : 20.0
# [INFO] Time remaining (min) : 19.9
# [INFO] Time remaining (min) : 18.4
# [INFO] Time remaining (min) : 19.0
# [INFO] Time remaining (min) : 18.9
# IN :  106
# [INFO] Time remaining (min) : 20.1
# IN :  107
# [INFO] Time remaining (min) : 20.0
# [INFO] Time remaining (min) : 18.5
# IN :  108
# [INFO] Time remaining (min) : 19.0
# IN :  109
# [INFO] Time remaining (min) : 19.6
# IN :  110
# IN :  111
# [INFO] Time remaining (min) : 19.5
# IN :  112
# [INFO] Time remaining (min) : 19.4
# [INFO] Time remaining (min) : 17.3
# IN :  113
# IN :  114
# [INFO] Time remaining (min) : 19.9
# [INFO] Time remaining (min) : 17.7
# [INFO] Time remaining (min) : 17.0
# IN :  115
# IN :  116
# [INFO] Time remaining (min) : 19.5
# [INFO] Time remaining (min) : 18.0
# IN :  117
# OUT :  105
# [INFO] Time remaining (min) : 19.2
# IN :  118
# [INFO] Time remaining (min) : 17.7
# [INFO] Time remaining (min) : 17.0
# [INFO] Time remaining (min) : 16.3
# IN :  119
# [INFO] Time remaining (min) : 17.4
# IN :  120
# [INFO] Time remaining (min) : 17.3
# [INFO] Time remaining (min) : 16.0
# [INFO] Time remaining (min) : 15.9
# IN :  121
# [INFO] Time remaining (min) : 16.3
# [INFO] Time remaining (min) : 15.7
# [INFO] Time remaining (min) : 16.1
# [INFO] Time remaining (min) : 16.0
# IN :  122
# [INFO] Time remaining (min) : 16.4
# [INFO] Time remaining (min) : 15.2
# [INFO] Time remaining (min) : 15.1
# [INFO] Time remaining (min) : 15.5
# [INFO] Time remaining (min) : 15.4
# [INFO] Time remaining (min) : 14.8
# [INFO] Time remaining (min) : 14.7
# [INFO] Time remaining (min) : 14.6
# [INFO] Time remaining (min) : 14.4
# [INFO] Time remaining (min) : 14.3
# [INFO] Time remaining (min) : 14.7
# [INFO] Time remaining (min) : 14.1
# [INFO] Time remaining (min) : 14.5
# [INFO] Time remaining (min) : 13.9
# [INFO] Time remaining (min) : 13.8
# [INFO] Time remaining (min) : 14.1
# [INFO] Time remaining (min) : 14.0
# [INFO] Time remaining (min) : 13.9
# [INFO] Time remaining (min) : 13.3
# [INFO] Time remaining (min) : 13.2
# [INFO] Time remaining (min) : 13.1
# [INFO] Time remaining (min) : 13.0
# OUT :  106
# OUT :  107
# [INFO] Time remaining (min) : 15.5
# [INFO] Time remaining (min) : 13.2
# [INFO] Time remaining (min) : 12.7
# [INFO] Time remaining (min) : 12.6
# [INFO] Time remaining (min) : 12.9
# [INFO] Time remaining (min) : 12.3
# OUT :  108
# [INFO] Time remaining (min) : 13.1
# [INFO] Time remaining (min) : 12.5
# [INFO] Time remaining (min) : 12.0
# [INFO] Time remaining (min) : 11.9
# [INFO] Time remaining (min) : 11.8
# [INFO] Time remaining (min) : 12.1
# [INFO] Time remaining (min) : 12.8
# [INFO] Time remaining (min) : 11.8
# [INFO] Time remaining (min) : 11.7
# [INFO] Time remaining (min) : 11.6
# [INFO] Time remaining (min) : 11.5
# [INFO] Time remaining (min) : 11.0
# [INFO] Time remaining (min) : 11.3
# [INFO] Time remaining (min) : 10.8
# OUT :  109
# [INFO] Time remaining (min) : 11.9
# [INFO] Time remaining (min) : 10.6
# IN :  123
# IN :  124
# [INFO] Time remaining (min) : 12.1
# [INFO] Time remaining (min) : 10.3
# [INFO] Time remaining (min) : 10.2
# [INFO] Time remaining (min) : 10.5
# IN :  125
# [INFO] Time remaining (min) : 10.7
# [INFO] Time remaining (min) : 10.2
# [INFO] Time remaining (min) : 10.1
# IN :  126
# [INFO] Time remaining (min) : 10.7
# [INFO] Time remaining (min) : 10.2
# [INFO] Time remaining (min) : 9.8
# [INFO] Time remaining (min) : 9.3
# [INFO] Time remaining (min) : 9.2
# [INFO] Time remaining (min) : 9.1
# [INFO] Time remaining (min) : 9.0
# [INFO] Time remaining (min) : 8.9
# [INFO] Time remaining (min) : 8.8
# [INFO] Time remaining (min) : 8.7
# [INFO] Time remaining (min) : 8.6
# [INFO] Time remaining (min) : 8.4
# [INFO] Time remaining (min) : 8.6
# [INFO] Time remaining (min) : 9.5
# IN :  127
# IN :  128
# [INFO] Time remaining (min) : 8.4
# [INFO] Time remaining (min) : 8.0
# [INFO] Time remaining (min) : 8.2
# [INFO] Time remaining (min) : 7.8
# [INFO] Time remaining (min) : 7.9
# IN :  129
# [INFO] Time remaining (min) : 8.1
# [INFO] Time remaining (min) : 7.7
# [INFO] Time remaining (min) : 7.6
# OUT :  110
# [INFO] Time remaining (min) : 7.7
# [INFO] Time remaining (min) : 7.4
# [INFO] Time remaining (min) : 7.0
# OUT :  111
# [INFO] Time remaining (min) : 7.4
# [INFO] Time remaining (min) : 7.0
# [INFO] Time remaining (min) : 6.9
# [INFO] Time remaining (min) : 6.8
# [INFO] Time remaining (min) : 6.7
# [INFO] Time remaining (min) : 6.6
# [INFO] Time remaining (min) : 6.4
# [INFO] Time remaining (min) : 6.1
# OUT :  112
# [INFO] Time remaining (min) : 6.4
# [INFO] Time remaining (min) : 6.1
# [INFO] Time remaining (min) : 5.8
# [INFO] Time remaining (min) : 5.9
# OUT :  113
# [INFO] Time remaining (min) : 6.0
# [INFO] Time remaining (min) : 5.4
# IN :  130
# [INFO] Time remaining (min) : 5.7
# [INFO] Time remaining (min) : 5.6
# [INFO] Time remaining (min) : 5.3
# [INFO] Time remaining (min) : 5.2
# [INFO] Time remaining (min) : 5.1
# [INFO] Time remaining (min) : 4.9
# OUT :  114
# [INFO] Time remaining (min) : 5.0
# [INFO] Time remaining (min) : 5.1
# [INFO] Time remaining (min) : 4.6
# [INFO] Time remaining (min) : 4.5
# OUT :  115
# IN :  131
# IN :  132
# [INFO] Time remaining (min) : 5.1
# [INFO] Time remaining (min) : 4.1
# [INFO] Time remaining (min) : 4.0
# [INFO] Time remaining (min) : 3.9
# [INFO] Time remaining (min) : 3.9
# [INFO] Time remaining (min) : 3.8
# [INFO] Time remaining (min) : 3.7
# [INFO] Time remaining (min) : 3.4
# IN :  133
# [INFO] Time remaining (min) : 3.6
# [INFO] Time remaining (min) : 3.3
# IN :  134
# [INFO] Time remaining (min) : 3.5
# [INFO] Time remaining (min) : 3.1
# [INFO] Time remaining (min) : 3.1
# [INFO] Time remaining (min) : 2.9
# [INFO] Time remaining (min) : 2.8
# [INFO] Time remaining (min) : 2.6
# OUT :  116
# [INFO] Time remaining (min) : 2.5
# [INFO] Time remaining (min) : 2.3
# IN :  135
# [INFO] Time remaining (min) : 2.4
# [INFO] Time remaining (min) : 2.1
# [INFO] Time remaining (min) : 2.1
# OUT :  117
# [INFO] Time remaining (min) : 2.0
# [INFO] Time remaining (min) : 1.8
# [INFO] Time remaining (min) : 1.7
# [INFO] Time remaining (min) : 1.6
# [INFO] Time remaining (min) : 1.5
# [INFO] Time remaining (min) : 1.4
# [INFO] Time remaining (min) : 1.3
# [INFO] Time remaining (min) : 1.1
# [INFO] Time remaining (min) : 1.0
# [INFO] Time remaining (min) : 0.9
# [INFO] Time remaining (min) : 0.8
# [INFO] Time remaining (min) : 0.7
# [INFO] Time remaining (min) : 0.6
# [INFO] Time remaining (min) : 0.4
# [INFO] Time remaining (min) : 0.3
# [INFO] Time remaining (min) : 0.2
# [INFO] Time remaining (min) : 0.1
# [INFO] Time remaining (min) : 0.0
# Done processing !!!
# [INFO] approx. FPS: 15.08
# OUT :  117
# IN :  135
